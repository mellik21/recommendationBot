# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

data = pd.read_csv('cleaned_anime.csv')

# %% [markdown]
# # Визуализация
# **Что было бы интересно узнать?**
#  - Распределение по жанрам(сколько всего записей для каждого жанра существует)
#  - Серии с наибольшим числом сезонов(в каких сериях больше всего сезонов(можно считать от 2х)
#  - Какой временной промежуток представлен, временной ряд с числом аниме (с учетом сезонов) ✔
#  - Распределение по рейтингам (в каком промежутке рейтинга находится большее число аниме) ✔
#  - Распределение по студиям (отношение студии и числа выпущенных аниме)
#  - Какие жанры преобладают в более популярных аниме?

# %%
sns.set()
#sns.set_palette("Paired")
sns.set_palette("pastel")

# %%
data
# Out:
#       Page                                           Rus_name  \
# 0        1                        Стальной алхимик: Братство
# 1        1                                      Врата Штейна
# 2        1                                   Гинтама 4 сезон
# 3        1                          Охотник х Охотник (2011)
# 4        1                                   Гинтама 2 сезон
# ...    ...                                                ...
# 1912    80                                           АКБ0048
# 1913    80       Остров Забвения: Харука и волшебное зеркало
# 1914    80                                     Чей-то взгляд
# 1915    80       Трусливый велосипедист: Специальная поездка
# 1916    80  Ранма 1/2: Команда Ранмы против Легендарного ф...
#
#                                                Eng_name  \
# 0         Hagane no Renkinjutsushi (2009) / FMA (2009)
# 1                                          Steins;Gate
# 2                                             Gintama°
# 3                               Hunter x Hunter (2011)
# 4                                             Gintama'
# ...                                                 ...
# 1912                                           AKB0048
# 1913     Hottarake no Shima: Haruka to Mahou no Kagami
# 1914                               Dareka no Manazashi
# 1915                     Yowamushi Pedal: Special Ride
# 1916  Ranma ½: Chou Musabetsu Kessen! Ranma Team vs....
#
#                                                    Href  \
# 0           /catalog/hagane-no-renkinjutsushi-2009-2400
# 1                              /catalog/steins-gate-914
# 2                                 /catalog/gintama-9815
# 3                    /catalog/hunter-x-hunter-2011-4023
# 4                                  /catalog/gintama-216
# ...                                                 ...
# 1912                               /catalog/akb0048-493
# 1913  /catalog/hottarake-no-shima-haruka-to-mahou-no...
# 1914                  /catalog/dareka-no-manazashi-1112
# 1915         /catalog/yowamushi-pedal-special-ride-1851
# 1916  /catalog/ranma-chou-musabetsu-kessen-ranma-tea...
#
#                                                  Genres  Rating  \
# 0     ['Экшен', 'Военное', 'Приключения', 'Комедия',...     9.2
# 1                             ['Фантастика', 'Триллер']     9.1
# 2     ['Экшен', 'Комедия', 'Исторический', 'Пародия'...     9.1
# 3     ['Экшен', 'Приключения', 'Сёнен', 'Супер сила'...     9.1
# 4     ['Экшен', 'Комедия', 'Исторический', 'Пародия'...     9.1
# ...                                                 ...     ...
# 1912                           ['Музыка', 'Фантастика']     7.4
# 1913                                        ['Фэнтези']     7.4
# 1914                        ['Драма', 'Повседневность']     7.4
# 1915             ['Комедия', 'Драма', 'Сёнен', 'Спорт']     7.4
# 1916  ['Экшен', 'Приключения', 'Комедия', 'Боевые ис...     7.4
#
#                                             Description  \
# 0     Ремейк одноимённого аниме-сериала «Стальной ал...
# 1     Действие сериала происходит летом 2010 года в ...
# 2     Никто этого уже не ждал и не надеялся, но...\n...
# 3     Ремейк аниме-сериала «Охотник х Охотник» 1999 ...
# 4     Над древним Эдо, которым правит марионеточный ...
# ...                                                 ...
# 1912  В начале 21 века Мировая война достигает своег...
# 1913  Твой любимый плюшевый мишка. Старая, так и не ...
# 1914  Со временем вещи становятся обыденными и скучн...
# 1915  Сакамичи Онода — отаку, мечтающий найти друзей...
# 1916  Татэваки Куно покупает в одном антикварном маг...
#
#                                         Alt_description  \
# 0     Нарушив главный запрет Алхимии и попытавшись в...
# 1     Акихабара – интереснейшее место, где обитают с...
# 2                                                   NaN
# 3     Жизнь в этой реальности устроена, как обычно –...
# 4     Продолжение приключений Гинтоки и его команды ...
# ...                                                 ...
# 1912  После очередной мировой войны человечество пот...
# 1913  16-летняя Харука в раннем детстве потеряла мат...
# 1914                                                NaN
# 1915                                                NaN
# 1916                                                NaN
#
#                                 Img  \
# 0     /posters/2400.10127424713.jpg
# 1      /posters/914.11477207553.jpg
# 2     /posters/9815.35700322133.jpg
# 3      /posters/4023.9592776303.jpg
# 4      /posters/216.40890160023.jpg
# ...                             ...
# 1912   /posters/493.28311515333.jpg
# 1913     /posters/722.582107413.jpg
# 1914  /posters/1112.22266925323.jpg
# 1915    /posters/1851.491422403.jpg
# 1916  /posters/2013.31601303103.jpg
#
#                                             Minor_names  \
# 0     ['Стальной алхимик: Братство ', ' Hagane no Re...
# 1     ['Врата Штейна ', ' シュタインズ・ゲート ', ' Steins Gat...
# 2     ['Gintama° ', ' Гинтама 4 ', ' Gintama (2015) ...
# 3     ['Hunter x Hunter (2011) ', ' Охотник х Охотни...
# 4     ['Гинтама 2 ', " Gintama' ", ' Gintama` ', ' 銀...
# ...                                                 ...
# 1912  ['АКБ0048 ', ' AKB0048 ', ' AKB0048: First Sta...
# 1913  ['Hottarake no Shima: Haruka to Mahou no Kagam...
# 1914  ['Чей-то взгляд ', ' Dareka no Manazashi ', ' ...
# 1915  ['Yowamushi Pedal: Special Ride ', ' Трусливый...
# 1916  ['Ranma ½: Chou Musabetsu Kessen! Ranma Team v...
#
#                                 Studio    Season    Year  \
# 0                                  NaN       NaN     NaN
# 1                                  NaN       NaN     NaN
# 2                                  NaN       NaN     NaN
# 3                                  NaN       NaN     NaN
# 4                                  NaN       NaN     NaN
# ...                                ...       ...     ...
# 1912                         Satelight  весеннем  2012.0
# 1913  Production I.G, Polygon Pictures    летнем  2009.0
# 1914                        CoMix Wave    зимнем  2013.0
# 1915                 TMS Entertainment    летнем  2013.0
# 1916                       Studio DEEN    летнем  1994.0
#
#                                       Season_name              Seria_name
# 0                                             NaN                     NaN
# 1                                             NaN                     NaN
# 2                                             NaN                     NaN
# 3                                             NaN                     NaN
# 4                                             NaN                     NaN
# ...                                           ...                     ...
# 1912                                          NaN                АКБ0048
# 1913                  Харука и волшебное зеркало          Остров Забвения
# 1914                                          NaN          Чей-то взгляд
# 1915                         Специальная поездка   Трусливый велосипедист
# 1916   Команда Ранмы против Легендарного феникса                Ранма 1/2
#
# [1917 rows x 15 columns]

# %%
#Распределение по годам
pd.to_numeric(data.Year, downcast='integer')

f, ax = plt.subplots(figsize=(20, 20))
sns.countplot(y="Year", data=data)

# %%
#Распределение по рейтингу
f, ax = plt.subplots(figsize=(10, 5))
sns.countplot(x="Rating", data=data)

# %%
#Распределение по студиям
#colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
#studio_df = data.Studio.value_counts()
#plot = studio_df.plot.pie(y='vals', figsize=(10, 10), autopct="%.1f%%")

# %%
#Распределение по студиям 
# РАБОТАЕТ НЕ ВЕРНО ТК ОДНО АНИМЕ МОГУТ ДЕЛАТЬ СРАЗУ НЕСКОЛЬКО СТУДИЙ, НАДО ЭТО УЧЕСТЬ"!!!!!!!
f, ax = plt.subplots(figsize=(10,60))
sns.countplot(y="Studio", data=data)
